# %% [markdown]
# #### Agenda
# 1. Revamp EM to work on grey scale image
# 2. Rewrite EM to record the stat and visualize
# 3. Plot the density estimate
# 4. Try randomized init and KMeans init
# 5. Strinkage of K
#
# #### Comparison
# 1. With random init v.s. KMeans init
# 2. KMeans v.s EM (Density Estimate, Image effect)
# 3. Selection of K
#
# #### Reference
# 1. Plot GMM density and plot AIC, BIC for different K http://www.astroml.org/book_figures/chapter4/fig_GMM_1D.html
# 2. AIC = s*k - 2 * lnL  https://en.wikipedia.org/wiki/Akaike_information_criterion
# 3.

# %%
import datetime
from dateutil.relativedelta import relativedelta

import numpy as np
from numpy.random import randint, random
import scipy.stats
import math
import cv2
from scipy import ndimage

from sklearn import cluster
from scipy.cluster.vq import kmeans2
import matplotlib.pyplot as plt
from scipy import ndimage


# input fllename >> output 3d array
def read_img(filename, mode, size):
    if mode == 'RGB':
        img_3d = ndimage.imread(filename, mode = 'RGB')
    elif mode == 'L':
        img_3d = ndimage.imread(filename, mode = 'L')
    # Downsample the image
    small = cv2.resize(img_3d, (0, 0), fx = size[0], fy = size[1])
    # Blurring effect to denoise
    blur = cv2.blur(small, (4, 4))
    return blur


# input 3d array >> output 2d array
def flatten_img(img_3d, mode):
    if mode == 'RGB':
        x, y, z = img_3d.shape
        img_2d = img_3d.reshape(x*y, z)
        img_2d = np.array(img_2d, dtype = np.float)
    elif mode == 'L':
        x, y = img_3d.shape
        img_2d = img_3d.reshape(x*y, 1)
        img_2d = np.array(img_2d, dtype = np.float)
    return img_2d


# input 2d array >> output 3d array
def recover_img(img_2d, X, Y, mode = 'RGB', vis = False):
    #img_2d = cv2.resize(img_2d, (0, 0), fx=10, fy=10)
    if mode == 'RGB':
        img_2d = (img_2d * 255).astype(np.uint8)
        recover_img = img_2d.reshape(X, Y, 3)
    elif mode == 'L':
        recover_img = img_2d.reshape(X, Y)
    return recover_img


# input 2d array >> output estimated means, stds, pis
def kmeans_init(img, k):
    means, labels = kmeans2(img, k)
    try:
        means = np.array(means)
        cov = np.array([np.cov(img[labels == i].T) for i in range(k)])
        ids = set(labels)
        pis = np.array([np.sum([labels == i]) / len(labels) for i in ids])
    except Exception as ex:
        pass
    return means, cov, pis

def random_init(img, k):
    # For gray-scale
    if len(img.shape) == 1:
        means = randint(low = 0, high = 255, size = (k,1))
        cov = randint(low = 0, high = 500, size = k)
        pis = random(size = k)
    else:
        z = img.shape[1]
        means = randint(low = 0, high = 255, size = (k , z))
        cov = randint(low = 0, high = 500, size = (k, z, z))
        pis = random(size = k)
    return means, cov, pis


# E-Step: Update Parameters
# update the conditional pdf - prob that pixel i given class j
def update_responsibility(img, means, cov, pis, k):
    # responsibilities: i th pixels, j th class
    # pis * gaussian.pdf
    responsibilities = np.array([pis[j] * scipy.stats.multivariate_normal.pdf(img, mean=means[j], cov=cov[j]) for j in range(k)]).T
    # normalize for each row
    norm = np.sum(responsibilities, axis = 1)
    # convert to column vector
    norm = np.reshape(norm, (len(norm), 1))
    responsibilities = responsibilities / norm
    return responsibilities


# update pi for each class of Gaussian model
def update_pis(responsibilities):
    pis = np.sum(responsibilities, axis = 0) / responsibilities.shape[0]
    return pis

# update means for each class of Gaussian model
def update_means(img, responsibilities):
    means = []
    class_n = responsibilities.shape[1]
    for j in range(class_n):
        weight = responsibilities[:, j] / np.sum(responsibilities[:, j])
        weight = np.reshape(weight, (1, len(weight)))
        means_j = weight.dot(img)
        means.append(means_j[0])
    means = np.array(means)
    return means

# update covariance matrix for each class of Gaussian model
def update_covariance(img, responsibilities, means):
    cov = []
    class_n = responsibilities.shape[1]
    for j in range(class_n):
        weight = responsibilities[:, j] / np.sum(responsibilities[:, j])
        weight = np.reshape(weight, (1, len(weight)))
        # Each pixels have a covariance matrice
        covs = [np.mat(i - means[j]).T * np.mat(i - means[j]) for i in img]
        # Weighted sum of covariance matrices
        cov_j = sum(weight[0][i] * covs[i] for i in range(len(weight[0])))
        cov.append(cov_j)
    cov = np.array(cov)
    return cov


# M-step: choose a label that maximise the likelihood
def update_labels(responsibilities):
    labels = np.argmax(responsibilities, axis = 1)
    return labels


def update_loglikelihood(img, means, cov, pis, k):
    pdf = np.array([pis[j] * scipy.stats.multivariate_normal.pdf(img, mean=means[j], cov=cov[j]) for j in range(k)])
    log_ll = np.log(np.sum(pdf, axis = 0))
    log_ll_sum = np.sum(log_ll)
    return log_ll_sum


def EM_cluster(img, k, random = False, error = 10e-4, iter_n = 9999):
    #  init setting
    cnt = 0
    likelihood_arr = []
    means_arr = []
    if not random:
        # Initialise E-Step by KMeans
        means, cov, pis = kmeans_init(img, k)
    else:
        means, cov, pis = random_init(img, k)
    likelihood = 0
    new_likelihood = 2
    means_arr.append(means)
    responsibilities = update_responsibility(img, means, cov, pis, k)
    while (abs(likelihood - new_likelihood) > error) and (cnt != iter_n):
        start_dt = datetime.datetime.now()
        cnt += 1
        likelihood = new_likelihood
        # M-Step
        labels = update_labels(responsibilities)
        # E-step
        responsibilities = update_responsibility(img, means, cov, pis, k)
        means = update_means(img, responsibilities)
        cov = update_covariance(img, responsibilities, means)
        pis = update_pis(responsibilities)
        new_likelihood = update_loglikelihood(img, means, cov, pis, k)
        likelihood_arr.append(new_likelihood)
        end_dt = datetime.datetime.now()
        diff = relativedelta(end_dt, start_dt)
        print("iter: %s, time interval: %s:%s:%s:%s" % (cnt, diff.hours, diff.minutes, diff.seconds, diff.microseconds))
        print("log-likelihood = {}".format(new_likelihood))
        # Store means stat
        means_arr.append(means)
    likelihood_arr = np.array(likelihood_arr)
    print('Converge at iteration {}'.format(cnt + 1))
    return labels, means, cov, pis, likelihood_arr, means_arr

# %%
def get_pdf(y, means, cov, pis, k):
    pdf_arr = np.array([pis[j] * scipy.stats.multivariate_normal.pdf(y, mean=means[j], cov=cov[j]) for j in range(k)])
    pdf = np.sum(pdf_arr)
    return pdf

# %%
FILENAME_LIST = ['./img/gray_animal_1.jpg', './img/gray_animal_2.jpeg', './img/gray_animal_3.jpeg']

# %%
# Visualize demo images
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (15,15))
ax_list = [ax1, ax2, ax3]
gray_img_list = []
dim_img_list = []
i = 1
for filename, ax in zip(FILENAME_LIST, ax_list):
    gray_img = read_img(filename = filename, mode = 'L', size = (0.5, 0.5))
    x, y = gray_img.shape
    # Store dimension for each image
    dim_img_list.append((x,y))
    # Store img 
    gray_img_list.append(gray_img)
    ax.imshow(gray_img, cmap = 'gray')
    ax.set_title('[Image {}] Original Image'.format(i))
    ax.axes.set_xlabel('x-coordinate')
    ax.axes.set_ylabel('y-coordinate')
    i += 1;

plt.tight_layout()
fig.savefig('orig_images.pdf')

# %% [markdown]
# ### GET K-MEANS IMAGES - K=2

# %%
img_list = [flatten_img(image, mode = 'L') for image in gray_img_list]

# %%
# Run and Store KMeans image
from sklearn import cluster
from scipy.cluster.vq import kmeans2
kmeans_img_list = []
for img, dim in zip(img_list, dim_img_list):
    k_means, k_labels = kmeans2(img, 2)
    kmeans_img = np.array([i[0] for i in k_means[k_labels]])
    kmeans_img = kmeans_img.reshape(dim[0], dim[1])
    kmeans_img_list.append(kmeans_img)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (15,15))
ax_list = [ax1, ax2, ax3]
i = 1
for kmeans_img, ax, dim in zip(kmeans_img_list, ax_list, dim_img_list):
    ax.imshow(kmeans_img, cmap = 'gray')
    ax.set_title('[Image {}] Segmentation by KMeans'.format(i))
    ax.axes.set_xlabel('x-coordinate')
    ax.axes.set_ylabel('y-coordinate')
    i += 1;
    
plt.tight_layout()
fig.savefig('kmeans_images.pdf')

# %% [markdown]
# ### GET EM (WITH KMEANS INIT) IMAGES AND STAT - K=2

# %%
# Init container
likelihood_arr_list = []
means_arr_list = []
cov_arr_list = []
pis_arr_list = []
em_img_list = []
means_list = []

for img, dim in zip(img_list, dim_img_list):
    labels, means, cov, pis, likelihood_arr, means_arr = EM_cluster(img, 2, error = 0.001)
    means = np.array([element[0] for element in means])
    cov = [element[0][0] for element in cov]
    em_img = means[labels]
    recover_img = em_img.reshape(dim[0], dim[1])
    # store required stat
    likelihood_arr_list.append(likelihood_arr)
    means_arr_list.append(means_arr)
    cov_arr_list.append(cov)
    pis_arr_list.append(pis)
    em_img_list.append(recover_img)
    means_list.append(means)
# Out:
# iter: 1, time interval: 0:0:6:383310
# log-likelihood = -319941.291646223
# iter: 2, time interval: 0:0:6:724666
# log-likelihood = -314815.97399255104
# iter: 3, time interval: 0:0:6:401191
# log-likelihood = -307941.71465041663
# iter: 4, time interval: 0:0:6:300318
# log-likelihood = -298647.45940667426
# iter: 5, time interval: 0:0:6:211003
# log-likelihood = -285817.97520921857
# iter: 6, time interval: 0:0:6:273449
# log-likelihood = -268461.78259931883
# iter: 7, time interval: 0:0:6:4549
# log-likelihood = -247755.66468359588
# iter: 8, time interval: 0:0:6:680357
# log-likelihood = -225283.0978176563
# iter: 9, time interval: 0:0:7:74405
# log-likelihood = -179118.83510081656
# iter: 10, time interval: 0:0:6:301162
# log-likelihood = 394103.95236395585
# iter: 11, time interval: 0:0:9:427851
# log-likelihood = 385519.41769323696
# iter: 12, time interval: 0:0:8:605186
# log-likelihood = 385519.41769323696
# Converge at iteration 13
# iter: 1, time interval: 0:0:1:652163
# log-likelihood = -62743.14357246259
# iter: 2, time interval: 0:0:1:542313
# log-likelihood = -61728.35476498582
# iter: 3, time interval: 0:0:1:600462
# log-likelihood = -60013.57368763912
# iter: 4, time interval: 0:0:1:519141
# log-likelihood = -57338.5363631864
# iter: 5, time interval: 0:0:1:547144
# log-likelihood = -53587.723061850535
# iter: 6, time interval: 0:0:1:821351
# log-likelihood = -49789.68992677564
# iter: 7, time interval: 0:0:1:690463
# log-likelihood = -46968.3565316934
# iter: 8, time interval: 0:0:1:567472
# log-likelihood = -45856.73994809528
# iter: 9, time interval: 0:0:1:672508
# log-likelihood = -43715.35863514175
# iter: 10, time interval: 0:0:1:477087
# log-likelihood = -17535.816635555304
# iter: 11, time interval: 0:0:1:621421
# log-likelihood = 77071.89282224618
# iter: 12, time interval: 0:0:1:707155
# log-likelihood = 79542.68727816959
# iter: 13, time interval: 0:0:1:482650
# log-likelihood = 79542.68727816957
# Converge at iteration 14
# iter: 1, time interval: 0:0:1:556732
# log-likelihood = -61264.285075768144
# iter: 2, time interval: 0:0:1:501632
# log-likelihood = -59386.2255783923
# iter: 3, time interval: 0:0:1:495316
# log-likelihood = -57092.47796806931
# iter: 4, time interval: 0:0:1:698156
# log-likelihood = -54594.88606672307
# iter: 5, time interval: 0:0:1:478303
# log-likelihood = -52022.66595820997
# iter: 6, time interval: 0:0:1:665260
# log-likelihood = -49791.94321291677
# iter: 7, time interval: 0:0:1:615542
# log-likelihood = -48737.41204596105
# iter: 8, time interval: 0:0:1:474537
# log-likelihood = -48267.75071346737
# iter: 9, time interval: 0:0:1:643621
# log-likelihood = -47907.827772583325
# iter: 10, time interval: 0:0:1:466486
# log-likelihood = -47891.903599973615
# iter: 11, time interval: 0:0:1:667281
# log-likelihood = -47891.168379090275
# iter: 12, time interval: 0:0:1:746486
# log-likelihood = -47891.111289526845
# iter: 13, time interval: 0:0:1:465606
# log-likelihood = -47891.10637605013
# iter: 14, time interval: 0:0:1:536435
# log-likelihood = -47891.105940712296
# Converge at iteration 15

# %%
# Store density estimate (i.e pdf)
pdf_arr_list = []
for em_img, means, cov, pis in zip(em_img_list, means_list, cov_arr_list, pis_arr_list):
    pdf_arr = [get_pdf(i, means, cov, pis, 2) for i in np.linspace(0, 255, 256)]
    pdf_arr_list.append(pdf_arr)

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9), (ax10, ax11, ax12)) = plt.subplots(4, 3, figsize = (15,15))
ax_list = [ax1, ax2, ax3]
i = 1
# FIRST ROW: display image segment
for em_img, ax in zip(em_img_list, ax_list):
    ax.imshow(em_img, cmap = 'gray')
    ax.set_title('[Image {}] Segmentation by EM'.format(i))
    # Set x-axis, y-axis
    ax.axes.set_xlabel('x-coordinate')
    ax.axes.set_ylabel('y-coordinate')
    i += 1;

# SECOND ROW: display density estimate
ax_list = [ax4, ax5, ax6]
i = 1
for img, pdf, ax in zip(img_list, pdf_arr_list, ax_list):
    ax.hist(img, bins = 30, normed = True, alpha = 0.5, label='Histogram')
    ax.plot(pdf, 'r--', linewidth = 2, label = 'Estimated GMM')
    ax.set_title('[Image {}] Density Estimate of Intensity'.format(i))
    ax.legend()
    # Set x-axis, y-axis
    ax.axes.set_xlabel('Intensity')
    ax.axes.set_ylabel('Probability')
    # Strink the y-axis
    ax.set_ylim(0, 0.06)    
    i += 1;
    
# THIRD ROW: density estimate
ax_list = [ax7, ax8, ax9]
i = 1
for ll, ax in zip(likelihood_arr_list, ax_list):
    ax.plot(ll, 'g-')
    ax.set_title('[Image {}] Likelihood Estimate over Iterations'.format(i))
    # Set x-axis, y-axis
    ax.axes.set_xlabel('Iterations')
    ax.axes.set_ylabel('Likelihood Estimate')
    i += 1

# FOURTH ROW: displays means evolution over iteration
ax_list = [ax10, ax11, ax12]
i = 1
for m, ax in zip(means_arr_list, ax_list):
    # The 2nd image has class label inversed
    if i == 2:
        # Remove inner index
        m1 = [i[1][0] for i in m]
        m2 = [i[0][0] for i in m]
    else:       
        m1 = [i[0][0] for i in m]
        m2 = [i[1][0] for i in m]
    ax.plot(m1, 'r--', label = 'Class 1')
    ax.plot(m2, 'b-', label = 'Class 2')
    ax.set_title('[Image {}] Mean Evolution for each Class'.format(i))
    ax.legend(loc = 4)
    # Set x-axis, y-axis
    ax.axes.set_xlabel('Iterations')
    ax.axes.set_ylabel('Mean Estimate')
    i += 1

# Make a nice layout
plt.tight_layout();
plt.savefig("em_kmeans_init.pdf")

# %% [markdown]
# ### GET EM (WITH RANDOM INIT) IMAGES AND STAT - K=2

# %%
# Init container
rand_likelihood_arr_list = []
rand_means_arr_list = []
rand_cov_arr_list = []
rand_pis_arr_list = []
rand_em_img_list = []
rand_means_list = []

for img, dim in zip(img_list, dim_img_list):
    labels, means, cov, pis, likelihood_arr, means_arr = EM_cluster(img, 2, random = True, error = 0.001)
    means = np.array([element[0] for element in means])
    cov = [element[0][0] for element in cov]
    em_img = means[labels]
    recover_img = em_img.reshape(dim[0], dim[1])
    # store required stat
    rand_likelihood_arr_list.append(likelihood_arr)
    rand_means_arr_list.append(means_arr)
    rand_cov_arr_list.append(cov)
    rand_pis_arr_list.append(pis)
    rand_em_img_list.append(recover_img)
    rand_means_list.append(means)
# Out:
# iter: 1, time interval: 0:0:6:546998
# log-likelihood = -334102.24797822186
# iter: 2, time interval: 0:0:6:381705
# log-likelihood = -333778.69974770304
# iter: 3, time interval: 0:0:6:304966
# log-likelihood = -333566.7850975388
# iter: 4, time interval: 0:0:6:278851
# log-likelihood = -333337.264399434
# iter: 5, time interval: 0:0:6:516986
# log-likelihood = -333073.5901913951
# iter: 6, time interval: 0:0:6:546472
# log-likelihood = -332766.5266503487
# iter: 7, time interval: 0:0:6:241743
# log-likelihood = -332405.94865644455
# iter: 8, time interval: 0:0:6:431830
# log-likelihood = -331979.11160730314
# iter: 9, time interval: 0:0:6:177685
# log-likelihood = -331468.3999779005
# iter: 10, time interval: 0:0:6:206172
# log-likelihood = -330847.07659780513
# iter: 11, time interval: 0:0:5:756503
# log-likelihood = -330071.6270566794
# iter: 12, time interval: 0:0:6:242706
# log-likelihood = -329068.5571297122
# iter: 13, time interval: 0:0:6:265929
# log-likelihood = -327713.22611937515
# iter: 14, time interval: 0:0:6:188492
# log-likelihood = -325802.4073303734
# iter: 15, time interval: 0:0:6:199283
# log-likelihood = -323037.71997210913
# iter: 16, time interval: 0:0:6:391940
# log-likelihood = -319063.7185932893
# iter: 17, time interval: 0:0:6:182047
# log-likelihood = -313589.3759726935
# iter: 18, time interval: 0:0:6:208166
# log-likelihood = -306290.9355689608
# iter: 19, time interval: 0:0:6:360031
# log-likelihood = -296389.14713753515
# iter: 20, time interval: 0:0:6:151859
# log-likelihood = -282747.72157086985
# iter: 21, time interval: 0:0:6:253552
# log-likelihood = -264501.3119440487
# iter: 22, time interval: 0:0:6:154862
# log-likelihood = -243155.83467095566
# iter: 23, time interval: 0:0:6:363926
# log-likelihood = -218478.9366484743
# iter: 24, time interval: 0:0:6:40252
# log-likelihood = -89275.06014253917
# iter: 25, time interval: 0:0:6:418654
# log-likelihood = 385519.41769235494
# iter: 26, time interval: 0:0:6:282356
# log-likelihood = 385519.41769323696
# Converge at iteration 27
# iter: 1, time interval: 0:0:1:359623
# log-likelihood = -66536.2398172807
# iter: 2, time interval: 0:0:1:246166
# log-likelihood = -66433.64907904674
# iter: 3, time interval: 0:0:1:337066
# log-likelihood = -66363.33113756741
# iter: 4, time interval: 0:0:1:273746
# log-likelihood = -66292.35324121974
# iter: 5, time interval: 0:0:1:243596
# log-likelihood = -66216.58065647451
# iter: 6, time interval: 0:0:1:329459
# log-likelihood = -66135.21673400134
# iter: 7, time interval: 0:0:1:252669
# log-likelihood = -66047.90155978428
# iter: 8, time interval: 0:0:1:378321
# log-likelihood = -65954.15512639692
# iter: 9, time interval: 0:0:1:489480
# log-likelihood = -65853.16908785836
# iter: 10, time interval: 0:0:1:512200
# log-likelihood = -65743.64845123078
# iter: 11, time interval: 0:0:1:370875
# log-likelihood = -65623.66037083573
# iter: 12, time interval: 0:0:1:380940
# log-likelihood = -65490.47336553071
# iter: 13, time interval: 0:0:1:358392
# log-likelihood = -65340.33143633313
# iter: 14, time interval: 0:0:1:337556
# log-likelihood = -65168.0417978946
# iter: 15, time interval: 0:0:1:479898
# log-likelihood = -64966.20064927
# iter: 16, time interval: 0:0:1:323474
# log-likelihood = -64723.87878541612
# iter: 17, time interval: 0:0:1:338086
# log-likelihood = -64424.78466981697
# iter: 18, time interval: 0:0:1:332886
# log-likelihood = -64045.87109002359
# iter: 19, time interval: 0:0:1:320451
# log-likelihood = -63558.495508748376
# iter: 20, time interval: 0:0:1:259399
# log-likelihood = -62921.830334394115
# iter: 21, time interval: 0:0:1:411876
# log-likelihood = -62007.1287209156
# iter: 22, time interval: 0:0:1:328176
# log-likelihood = -60479.57868103848
# iter: 23, time interval: 0:0:1:347973
# log-likelihood = -58046.243396498656
# iter: 24, time interval: 0:0:1:426668
# log-likelihood = -54446.56393147401
# iter: 25, time interval: 0:0:1:323637
# log-likelihood = -50571.780882844076
# iter: 26, time interval: 0:0:1:404589
# log-likelihood = -47461.87855090722
# iter: 27, time interval: 0:0:1:285410
# log-likelihood = -45940.03710463873
# iter: 28, time interval: 0:0:1:371407
# log-likelihood = -44275.24899509852
# iter: 29, time interval: 0:0:1:389198
# log-likelihood = -26747.328431379497
# iter: 30, time interval: 0:0:1:272646
# log-likelihood = 77071.89280172088
# iter: 31, time interval: 0:0:1:432805
# log-likelihood = 79542.68727816959
# iter: 32, time interval: 0:0:1:312369
# log-likelihood = 79542.68727816957
# Converge at iteration 33
# iter: 1, time interval: 0:0:1:314907
# log-likelihood = -61999.60572909888
# iter: 2, time interval: 0:0:1:364806
# log-likelihood = -60175.003580072866
# iter: 3, time interval: 0:0:1:318009
# log-likelihood = -58037.040058313
# iter: 4, time interval: 0:0:1:272246
# log-likelihood = -55599.83840547863
# iter: 5, time interval: 0:0:1:367301
# log-likelihood = -53023.08489196006
# iter: 6, time interval: 0:0:1:262212
# log-likelihood = -50552.4555985624
# iter: 7, time interval: 0:0:1:330460
# log-likelihood = -48992.94477329486
# iter: 8, time interval: 0:0:1:274568
# log-likelihood = -48453.07819848406
# iter: 9, time interval: 0:0:1:316420
# log-likelihood = -47971.20067854757
# iter: 10, time interval: 0:0:1:365843
# log-likelihood = -47893.317739073784
# iter: 11, time interval: 0:0:1:249364
# log-likelihood = -47891.26471000552
# iter: 12, time interval: 0:0:1:364247
# log-likelihood = -47891.119294852644
# iter: 13, time interval: 0:0:1:591804
# log-likelihood = -47891.107078132045
# iter: 14, time interval: 0:0:1:392388
# log-likelihood = -47891.106003261484
# iter: 15, time interval: 0:0:1:239641
# log-likelihood = -47891.10590740865
# Converge at iteration 16

# %%
# Store density estimate (i.e pdf)
rand_pdf_arr_list = []
for em_img, means, cov, pis in zip(rand_em_img_list, rand_means_list, rand_cov_arr_list, rand_pis_arr_list):
    rand_pdf_arr = [get_pdf(i, means, cov, pis, 2) for i in np.linspace(0, 255, 256)]
    rand_pdf_arr_list.append(rand_pdf_arr)

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9), (ax10, ax11, ax12)) = plt.subplots(4, 3, figsize = (15,15))
ax_list = [ax1, ax2, ax3]
i = 1
# FIRST ROW: display image segment
for rand_em_img, ax in zip(rand_em_img_list, ax_list):
    ax.imshow(rand_em_img, cmap = 'gray')
    ax.set_title('[Image {}] Segmentation by EM'.format(i))
    # Set x-axis, y-axis
    ax.axes.set_xlabel('x-coordinate')
    ax.axes.set_ylabel('y-coordinate')
    i += 1;

# SECOND ROW: display density estimate
ax_list = [ax4, ax5, ax6]
i = 1
for img, pdf, ax in zip(img_list, rand_pdf_arr_list, ax_list):
    ax.hist(img, bins = 30, normed = True, alpha = 0.5, label='Histogram')
    ax.plot(pdf, 'r--', linewidth = 2, label = 'Estimated GMM')
    ax.set_title('[Image {}] Density Estimate of Intensity'.format(i))
    ax.legend()
    # Set x-axis, y-axis
    ax.axes.set_xlabel('Intensity')
    ax.axes.set_ylabel('Probability')
    # Strink the y-axis
    ax.set_ylim(0, 0.06)    
    i += 1;
    
# THIRD ROW: loglikelihood estimate
ax_list = [ax7, ax8, ax9]
i = 1
for ll, ax in zip(rand_likelihood_arr_list, ax_list):
    ax.plot(ll, 'g-')
    ax.set_title('[Image {}] Likelihood Estimate over Iterations'.format(i))
    # Set x-axis, y-axis
    ax.axes.set_xlabel('Iterations')
    ax.axes.set_ylabel('Loglikelihood Estimate')
    i += 1

# FOURTH ROW: displays means evolution over iteration
ax_list = [ax10, ax11, ax12]
i = 1
for m, ax in zip(rand_means_arr_list, ax_list):
    # The 1st image has class label inversed
    if i == 1:
        # Remove inner index
        m1 = [i[1][0] for i in m]
        m2 = [i[0][0] for i in m]
    else:       
        m1 = [i[0][0] for i in m]
        m2 = [i[1][0] for i in m]
    ax.plot(m1, 'r--', label = 'Class 1')
    ax.plot(m2, 'b-', label = 'Class 2')
    ax.set_title('[Image {}] Mean Evolution for each Class'.format(i))
    ax.legend(loc = 4)
    # Set x-axis, y-axis
    ax.axes.set_xlabel('Iterations')
    ax.axes.set_ylabel('Mean Estimate')
    i += 1

# Make a nice layout
plt.tight_layout();
fig.savefig('em_rand_init.pdf')

# %% [markdown]
# ### ADD NOISE DEMO

# %%
import numpy as np
import random
import cv2

def sp_noise(image,prob):
    '''
    Add salt and pepper noise to image
    prob: Probability of the noise
    '''
    output = np.zeros(image.shape,np.uint8)
    thres = 1 - prob 
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            rdn = random.random()
            if rdn < prob:
                output[i][j] = 0
            elif rdn > thres:
                output[i][j] = 255
            else:
                output[i][j] = image[i][j]
    return output

image = read_img('./img/gray_animal_1.jpg', mode = 'L', size = (0.6, 0.6)) # Only for grayscale image
noise_img = sp_noise(image,0.1)
x, y = noise_img.shape

# %%
plt.imshow(noise_img, cmap = 'gray');

# %%
flat_img =  flatten_img(noise_img, mode = 'L')
labels, means, cov, pis, likelihood_arr, means_arr = EM_cluster(flat_img, 2, error = 0.001)
means = np.array([element[0] for element in means])
cov = [element[0][0] for element in cov]
em_img = means[labels]
recover_img_1 = em_img.reshape(x, y)
plt.imshow(recover_img_1, cmap = 'gray');
# Out:
# iter: 1, time interval: 0:0:9:574050
# log-likelihood = -484503.11851024366
# iter: 2, time interval: 0:0:10:405315
# log-likelihood = -479875.72165235865
# iter: 3, time interval: 0:0:10:404287
# log-likelihood = -472748.6257953451
# iter: 4, time interval: 0:0:9:296360
# log-likelihood = -461956.45874123275
# iter: 5, time interval: 0:0:9:982423
# log-likelihood = -446101.87269489485
# iter: 6, time interval: 0:0:10:957534
# log-likelihood = -424276.2397151101
# iter: 7, time interval: 0:0:10:715413
# log-likelihood = -394642.4093791876
# iter: 8, time interval: 0:0:11:503015
# log-likelihood = -359317.6882307953
# iter: 9, time interval: 0:0:10:384829
# log-likelihood = -330372.9086622628
# iter: 10, time interval: 0:0:10:779808
# log-likelihood = -297344.0081088639
# iter: 11, time interval: 0:0:9:790549
# log-likelihood = 490963.49557115923
# iter: 12, time interval: 0:0:9:424216
# log-likelihood = 584885.8751039933
# iter: 13, time interval: 0:0:10:218372
# log-likelihood = 584885.8751039931
# Converge at iteration 14

# %%
blur_img = cv2.blur(noise_img, (4, 4))
plt.imshow(blur_img, cmap = 'gray');

# %%
flat_img =  flatten_img(blur_img, mode = 'L')
labels, means, cov, pis, likelihood_arr, means_arr = EM_cluster(flat_img, 2, error = 0.001)
means = np.array([element[0] for element in means])
cov = [element[0][0] for element in cov]
em_img = means[labels]
recover_img_2 = em_img.reshape(x, y)
plt.imshow(recover_img_2, cmap = 'gray');
# Out:
# iter: 1, time interval: 0:0:9:900944
# log-likelihood = -462040.3065923386
# iter: 2, time interval: 0:0:10:564107
# log-likelihood = -461772.87125472067
# iter: 3, time interval: 0:0:10:502347
# log-likelihood = -461550.90822576836
# iter: 4, time interval: 0:0:9:794347
# log-likelihood = -461345.018157089
# iter: 5, time interval: 0:0:10:51015
# log-likelihood = -461153.48818014853
# iter: 6, time interval: 0:0:9:631844
# log-likelihood = -460977.66537249146
# iter: 7, time interval: 0:0:9:582067
# log-likelihood = -460818.6698748887
# iter: 8, time interval: 0:0:8:973455
# log-likelihood = -460676.9243034135
# iter: 9, time interval: 0:0:9:292600
# log-likelihood = -460552.17800547654
# iter: 10, time interval: 0:0:9:917272
# log-likelihood = -460443.647453318
# iter: 11, time interval: 0:0:9:409550
# log-likelihood = -460350.1814070648
# iter: 12, time interval: 0:0:9:334526
# log-likelihood = -460270.4133139729
# iter: 13, time interval: 0:0:9:323472
# log-likelihood = -460202.8841533852
# iter: 14, time interval: 0:0:9:242254
# log-likelihood = -460146.1322043659
# iter: 15, time interval: 0:0:8:983329
# log-likelihood = -460098.7535958066
# iter: 16, time interval: 0:0:9:256194
# log-likelihood = -460059.44004656887
# iter: 17, time interval: 0:0:9:833720
# log-likelihood = -460026.9999600338
# iter: 18, time interval: 0:0:9:858006
# log-likelihood = -460000.3677787496
# iter: 19, time interval: 0:0:9:582655
# log-likelihood = -459978.6052092277
# iter: 20, time interval: 0:0:9:205203
# log-likelihood = -459960.8969291539
# iter: 21, time interval: 0:0:9:650882
# log-likelihood = -459946.5426971085
# iter: 22, time interval: 0:0:9:803902
# log-likelihood = -459934.94730597164
# iter: 23, time interval: 0:0:9:577061
# log-likelihood = -459925.6094684522
# iter: 24, time interval: 0:0:9:842258
# log-likelihood = -459918.11044321937
# iter: 25, time interval: 0:0:9:180515
# log-likelihood = -459912.10297822504
# iter: 26, time interval: 0:0:9:233935
# log-likelihood = -459907.30095552607
# iter: 27, time interval: 0:0:8:985301
# log-likelihood = -459903.4699668306
# iter: 28, time interval: 0:0:8:915684
# log-likelihood = -459900.41892935254
# iter: 29, time interval: 0:0:9:564496
# log-likelihood = -459897.9927641786
# iter: 30, time interval: 0:0:9:869458
# log-likelihood = -459896.0660996819
# iter: 31, time interval: 0:0:9:115603
# log-likelihood = -459894.5379252443
# iter: 32, time interval: 0:0:9:410984
# log-likelihood = -459893.32710038626
# iter: 33, time interval: 0:0:9:363220
# log-likelihood = -459892.3686165595
# iter: 34, time interval: 0:0:9:38409
# log-likelihood = -459891.61050939304
# iter: 35, time interval: 0:0:9:343495
# log-likelihood = -459891.01132494793
# iter: 36, time interval: 0:0:9:200659
# log-likelihood = -459890.5380522673
# iter: 37, time interval: 0:0:9:174084
# log-likelihood = -459890.1644445455
# iter: 38, time interval: 0:0:9:22903
# log-likelihood = -459889.86966153485
# iter: 39, time interval: 0:0:9:615296
# log-likelihood = -459889.63717566046
# iter: 40, time interval: 0:0:9:353877
# log-likelihood = -459889.4538933529
# iter: 41, time interval: 0:0:9:796936
# log-likelihood = -459889.3094511572
# iter: 42, time interval: 0:0:9:315974
# log-likelihood = -459889.195653169
# iter: 43, time interval: 0:0:9:841564
# log-likelihood = -459889.1060223394
# iter: 44, time interval: 0:0:10:639636
# log-likelihood = -459889.03544323513
# iter: 45, time interval: 0:0:10:235231
# log-likelihood = -459888.9798780519
# iter: 46, time interval: 0:0:10:207850
# log-likelihood = -459888.9361411686
# iter: 47, time interval: 0:0:9:99013
# log-likelihood = -459888.90172038524
# iter: 48, time interval: 0:0:9:979074
# log-likelihood = -459888.8746353268
# iter: 49, time interval: 0:0:11:636355
# log-likelihood = -459888.8533253864
# iter: 50, time interval: 0:0:10:104685
# log-likelihood = -459888.8365611182
# iter: 51, time interval: 0:0:9:203563
# log-likelihood = -459888.8233742218
# iter: 52, time interval: 0:0:9:243270
# log-likelihood = -459888.8130022507
# iter: 53, time interval: 0:0:9:335447
# log-likelihood = -459888.804844974
# iter: 54, time interval: 0:0:9:186758
# log-likelihood = -459888.7984299508
# iter: 55, time interval: 0:0:9:347368
# log-likelihood = -459888.79338538286
# iter: 56, time interval: 0:0:8:972927
# log-likelihood = -459888.7894187181
# iter: 57, time interval: 0:0:9:157029
# log-likelihood = -459888.7862997887
# iter: 58, time interval: 0:0:10:93763
# log-likelihood = -459888.7838475281
# iter: 59, time interval: 0:0:9:824170
# log-likelihood = -459888.7819195112
# iter: 60, time interval: 0:0:11:717055
# log-likelihood = -459888.7804037174
# iter: 61, time interval: 0:0:12:431567
# log-likelihood = -459888.779212047
# iter: 62, time interval: 0:0:11:655510
# log-likelihood = -459888.7782752176
# Converge at iteration 63

# %%
recover_img = em_img.reshape(x, y)
plt.imshow(recover_img, cmap = 'gray');

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex = True, sharey = True, figsize = (10,10))

ax1.imshow(noise_img, cmap = 'gray')
ax1.set_title('Original Image Before De-noise')

ax2.imshow(blur_img, cmap = 'gray')
ax2.set_title('Original Image After De-noise ')

ax3.imshow(recover_img_1, cmap = 'gray')
ax3.set_title('EM Segmentation Before De-noise ')

ax4.imshow(recover_img_2, cmap = 'gray')
ax4.set_title('EM Segmentation After De-noise ')

ax1.axes.set_xlabel('x-coordinate')
ax1.axes.set_ylabel('y-coordinate')

# SECOND ROW: log-likelihood evolution

plt.tight_layout()
fig.savefig('denoise_compare.pdf')

# %% [markdown]
# ### CAPTURE EM SEGMENT OVER DIFFERENT ITERATIONS

# %%
iter_num = [1, 10, 25]
demo_img_list = []
for n in iter_num:
    labels, means, cov, pis, likelihood_arr, means_arr = EM_cluster(flat_img, 2, error = 0.001, iter_n = n)
    cov = [element[0][0] for element in cov]
    em_img = means[labels]
    tmp_img = em_img.reshape(x, y)
    demo_img_list.append(tmp_img)
# Out:
# iter: 1, time interval: 0:0:9:893208
# log-likelihood = -462040.3065923386
# Converge at iteration 2
# iter: 1, time interval: 0:0:9:305010
# log-likelihood = -462040.3065923386
# iter: 2, time interval: 0:0:10:93379
# log-likelihood = -461772.87125472067
# iter: 3, time interval: 0:0:9:670879
# log-likelihood = -461550.90822576836
# iter: 4, time interval: 0:0:9:580765
# log-likelihood = -461345.018157089
# iter: 5, time interval: 0:0:9:515304
# log-likelihood = -461153.48818014853
# iter: 6, time interval: 0:0:9:682669
# log-likelihood = -460977.66537249146
# iter: 7, time interval: 0:0:9:254053
# log-likelihood = -460818.6698748887
# iter: 8, time interval: 0:0:10:88559
# log-likelihood = -460676.9243034135
# iter: 9, time interval: 0:0:9:490105
# log-likelihood = -460552.17800547654
# iter: 10, time interval: 0:0:9:273838
# log-likelihood = -460443.647453318
# Converge at iteration 11
# iter: 1, time interval: 0:0:9:305527
# log-likelihood = -462040.3065923386
# iter: 2, time interval: 0:0:9:399312
# log-likelihood = -461772.87125472067
# iter: 3, time interval: 0:0:9:354141
# log-likelihood = -461550.90822576836
# iter: 4, time interval: 0:0:8:998866
# log-likelihood = -461345.018157089
# iter: 5, time interval: 0:0:9:653460
# log-likelihood = -461153.48818014853
# iter: 6, time interval: 0:0:9:159593
# log-likelihood = -460977.66537249146
# iter: 7, time interval: 0:0:9:359114
# log-likelihood = -460818.6698748887
# iter: 8, time interval: 0:0:9:102669
# log-likelihood = -460676.9243034135
# iter: 9, time interval: 0:0:8:977244
# log-likelihood = -460552.17800547654
# iter: 10, time interval: 0:0:10:237844
# log-likelihood = -460443.647453318
# iter: 11, time interval: 0:0:9:706048
# log-likelihood = -460350.1814070648
# iter: 12, time interval: 0:0:9:60136
# log-likelihood = -460270.4133139729
# iter: 13, time interval: 0:0:11:951630
# log-likelihood = -460202.8841533852
# iter: 14, time interval: 0:0:9:929705
# log-likelihood = -460146.1322043659
# iter: 15, time interval: 0:0:10:75079
# log-likelihood = -460098.7535958066
# iter: 16, time interval: 0:0:9:835238
# log-likelihood = -460059.44004656887
# iter: 17, time interval: 0:0:9:778386
# log-likelihood = -460026.9999600338
# iter: 18, time interval: 0:0:9:886627
# log-likelihood = -460000.3677787496
# iter: 19, time interval: 0:0:9:844122
# log-likelihood = -459978.6052092277
# iter: 20, time interval: 0:0:10:30704
# log-likelihood = -459960.8969291539
# iter: 21, time interval: 0:0:9:905866
# log-likelihood = -459946.5426971085
# iter: 22, time interval: 0:0:9:710827
# log-likelihood = -459934.94730597164
# iter: 23, time interval: 0:0:10:137308
# log-likelihood = -459925.6094684522
# iter: 24, time interval: 0:0:9:912384
# log-likelihood = -459918.11044321937
# iter: 25, time interval: 0:0:9:876801
# log-likelihood = -459912.10297822504
# Converge at iteration 26

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (15,15))
ax_list = [ax1, ax2, ax3]
i = 1
# FIRST ROW: display image segment
for demo_img, n, ax in zip(demo_img_list, iter_num, ax_list):
    ax.imshow(demo_img, cmap = 'gray')
    ax.set_title('Image Segment by EM at Iteration {}'.format(n))
    # Set x-axis, y-axis
    ax.axes.set_xlabel('x-coordinate')
    ax.axes.set_ylabel('y-coordinate')
    i += 1;

plt.tight_layout()
fig.savefig('EM_iterations.pdf')
